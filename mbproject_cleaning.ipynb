# %% [markdown]
# # Overview and analysis of AirBnB listings in Barcelona
# In this project, we explore Airbnb listings in Barcelona, a city renowned for its tourism. With millions of annual visitors, Barcelona's popularity as a tourist destination significantly influences its hospitality sector. Airbnb, a major player in this landscape, shapes the city's lodging experience. This analysis focuses on key statistics and trends, aiming to reveal insights into the distribution, pricing dynamics, and trends of Airbnb listings across Barcelona's neighborhoods. Through data exploration, we aim to uncover patterns that provide a deeper understanding of the evolving Airbnb market in this vibrant Mediterranean city.

# %% [markdown]
# ![Barcelona](https://media.traveler.es/photos/63838947050e0f92cd80c982/16:9/w_2560%2Cc_limit/GettyImages-1392907424.jpg)

# %% [markdown]
# ## Structure of the notebook
# 1. Loading and exploring dataset
# 2. Cleaning dataset
# 3. Gathering data insights through aggregation and filtering
# 5. Exploratory data analysis - visualization
# 6. Hypothesis testing
# 7. Data preprocessing
# 8. Prediction of listing price based on other variables

# %% [markdown]
# ## 1. Loading and exploring dataset

# %%
# Importing libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st

# %%
# Loading dataset
data = pd.read_csv('data/raw/listings.csv')

# Since we have 75 columns, we want pandas to display all of them
pd.set_option('display.max_columns', None)

# Exploring first 5 rows
data.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   18674   https://www.airbnb.com/rooms/18674  20230906022853   2023-09-06
# 1   23197   https://www.airbnb.com/rooms/23197  20230906022853   2023-09-06
# 2  117010  https://www.airbnb.com/rooms/117010  20230906022853   2023-09-06
# 3   32711   https://www.airbnb.com/rooms/32711  20230906022853   2023-09-06
# 4  118228  https://www.airbnb.com/rooms/118228  20230906022853   2023-09-06
#
#             source                                               name  \
# 0      city scrape  Rental unit in Barcelona · ★4.30 · 3 bedrooms ...
# 1      city scrape  Rental unit in Sant Adria de Besos · ★4.77 · 3...
# 2  previous scrape  Rental unit in Barcelona · ★4.55 · 3 bedrooms ...
# 3      city scrape  Rental unit in Barcelona · ★4.46 · 2 bedrooms ...
# 4  previous scrape  Rental unit in Barcelona · ★4.56 · 3 bedrooms ...
#
#                                          description  \
# 0  110m2 apartment to rent in Barcelona. Located ...
# 1  Beautiful spacious apartment, large terrace, 5...
# 2  Have an authentic Barcelona experience! Modern...
# 3  A lovely two bedroom apartment only 250 m from...
# 4  Modern 100m2 recently decorated apartment with...
#
#                                neighborhood_overview  \
# 0  Apartment in Barcelona located in the heart of...
# 1  Strategically located in the Parc del Fòrum, a...
# 2  Apartment is located just 240 meters from Sagr...
# 3  What's nearby  <br />This apartment is located...
# 4  Apartment is located just 240 meters from Sagr...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/13031453/413c...    71615
# 1  https://a0.muscache.com/pictures/miso/Hosting-...    90417
# 2  https://a0.muscache.com/pictures/4052d8b5-7352...   567180
# 3  https://a0.muscache.com/pictures/357b25e4-f414...   135703
# 4  https://a0.muscache.com/pictures/c4b34854-5db1...   567180
#
#                                    host_url         host_name  host_since  \
# 0   https://www.airbnb.com/users/show/71615  Mireia And Maria  2010-01-19
# 1   https://www.airbnb.com/users/show/90417    Etain (Marnie)  2010-03-09
# 2  https://www.airbnb.com/users/show/567180            Sandra  2011-05-08
# 3  https://www.airbnb.com/users/show/135703              Nick  2010-05-31
# 4  https://www.airbnb.com/users/show/567180            Sandra  2011-05-08
#
#       host_location                                         host_about  \
# 0  Barcelona, Spain  We are Mireia (47) & Maria (49), two multiling...
# 1  Catalonia, Spain  Hi there, I'm marnie from Australia, though I ...
# 2  Barcelona, Spain   Suite Home Sagrada Familia is a complex of ap...
# 3  Barcelona, Spain  I'm Nick your English host in Barcelona.\r\n\r...
# 4  Barcelona, Spain   Suite Home Sagrada Familia is a complex of ap...
#
#    host_response_time host_response_rate host_acceptance_rate  \
# 0      within an hour                97%                  90%
# 1      within an hour               100%                  94%
# 2  within a few hours                88%                  98%
# 3      within an hour               100%                 100%
# 4  within a few hours                88%                  98%
#
#   host_is_superhost                                 host_thumbnail_url  \
# 0                 f  https://a0.muscache.com/im/users/71615/profile...
# 1                 t  https://a0.muscache.com/im/pictures/user/44b56...
# 2                 f  https://a0.muscache.com/im/pictures/user/7aaeb...
# 3                 f  https://a0.muscache.com/im/users/135703/profil...
# 4                 f  https://a0.muscache.com/im/pictures/user/7aaeb...
#
#                                     host_picture_url  \
# 0  https://a0.muscache.com/im/users/71615/profile...
# 1  https://a0.muscache.com/im/pictures/user/44b56...
# 2  https://a0.muscache.com/im/pictures/user/7aaeb...
# 3  https://a0.muscache.com/im/users/135703/profil...
# 4  https://a0.muscache.com/im/pictures/user/7aaeb...
#
#                 host_neighbourhood  host_listings_count  \
# 0               la Sagrada Família                 47.0
# 1            El Besòs i el Maresme                  6.0
# 2               la Sagrada Familia                 19.0
# 3  Camp d'en Grassot i Gràcia Nova                  3.0
# 4               la Sagrada Familia                 19.0
#
#    host_total_listings_count                host_verifications  \
# 0                       48.0                ['email', 'phone']
# 1                        9.0                ['email', 'phone']
# 2                       19.0                ['email', 'phone']
# 3                       15.0  ['email', 'phone', 'work_email']
# 4                       19.0                ['email', 'phone']
#
#   host_has_profile_pic host_identity_verified  \
# 0                    t                      t
# 1                    t                      t
# 2                    t                      f
# 3                    t                      t
# 4                    t                      f
#
#                            neighbourhood              neighbourhood_cleansed  \
# 0                   Barcelona, CT, Spain                  la Sagrada Família
# 1  Sant Adria de Besos, Barcelona, Spain               el Besòs i el Maresme
# 2            Barcelona, Catalonia, Spain                  la Sagrada Família
# 3            Barcelona, Catalonia, Spain  el Camp d'en Grassot i Gràcia Nova
# 4            Barcelona, Catalonia, Spain                  la Sagrada Família
#
#   neighbourhood_group_cleansed   latitude  longitude       property_type  \
# 0                     Eixample  41.405560    2.17262  Entire rental unit
# 1                   Sant Martí  41.412432    2.21975  Entire rental unit
# 2                     Eixample  41.406470    2.17457  Entire rental unit
# 3                       Gràcia  41.405660    2.17015  Entire rental unit
# 4                     Eixample  41.406530    2.17460  Entire rental unit
#
#          room_type  accommodates  bathrooms bathrooms_text  bedrooms  beds  \
# 0  Entire home/apt             8        NaN        2 baths       3.0   6.0
# 1  Entire home/apt             5        NaN        2 baths       3.0   4.0
# 2  Entire home/apt             8        NaN        2 baths       3.0   6.0
# 3  Entire home/apt             6        NaN      1.5 baths       2.0   3.0
# 4  Entire home/apt             8        NaN      2.5 baths       3.0   5.0
#
#                                            amenities    price  minimum_nights  \
# 0  ["Refrigerator", "30\" TV", "Iron", "Hangers",...  $202.00               1
# 1  ["Refrigerator", "Toaster", "Cleaning products...  $255.00               3
# 2  ["Refrigerator", "Clothing storage: closet and...  $331.00               2
# 3  ["Refrigerator", "Fire extinguisher", "First a...  $171.00              21
# 4  ["Refrigerator", "Clothing storage: closet and...  $333.00               2
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0            1125                       1                       4
# 1             300                       3                       5
# 2              30                       2                       3
# 3              31                       1                       1
# 4              28                       2                       3
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                    1125                    1125                     2.2
# 1                    1125                    1125                     3.2
# 2                      30                      32                     2.0
# 3                      31                      31                     1.0
# 4                      28                      32                     2.1
#
#    maximum_nights_avg_ntm  calendar_updated has_availability  availability_30  \
# 0                  1125.0               NaN                t                4
# 1                  1125.0               NaN                t               16
# 2                    30.3               NaN                f                0
# 3                    31.0               NaN                t                6
# 4                    28.7               NaN                f                0
#
#    availability_60  availability_90  availability_365 calendar_last_scraped  \
# 0               11               21                34            2023-09-06
# 1               31               61               150            2023-09-06
# 2                0                0                 0            2023-09-06
# 3               17               43               310            2023-09-06
# 4                0                0                 0            2023-09-06
#
#    number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                 38                      8                       0
# 1                 73                     11                       1
# 2                 48                      6                       1
# 3                 95                     21                       1
# 4                 50                     18                       0
#
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0   2013-05-27  2023-06-26                  4.30                    4.41
# 1   2011-03-15  2023-08-15                  4.77                    4.93
# 2   2011-08-09  2023-08-13                  4.55                    4.59
# 3   2011-07-17  2023-08-18                  4.46                    4.44
# 4   2011-09-13  2023-07-29                  4.56                    4.50
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       4.62                   4.76
# 1                       4.89                   4.94
# 2                       4.57                   4.82
# 3                       4.47                   4.86
# 4                       4.62                   4.56
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.65                    4.78                 4.27
# 1                         4.99                    4.60                 4.64
# 2                         4.91                    4.86                 4.59
# 3                         4.85                    4.86                 4.52
# 4                         4.74                    4.90                 4.52
#
#        license instant_bookable  calculated_host_listings_count  \
# 0  HUTB-002062                t                              30
# 1   HUTB005057                f                               2
# 2   HUTB000331                f                              19
# 3  HUTB-001722                t                               3
# 4  HUTB-000328                f                              19
#
#    calculated_host_listings_count_entire_homes  \
# 0                                           30
# 1                                            2
# 2                                           19
# 3                                            3
# 4                                           19
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.30
# 1                                            0               0.48
# 2                                            0               0.33
# 3                                            0               0.64
# 4                                            0               0.34

# %%
# Checking the shape of the dataframe

data.shape
# Out:
# (18086, 75)

# %%
# Checking dataframe information

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18086 entries, 0 to 18085
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            18086 non-null  int64
#  1   listing_url                                   18086 non-null  object
#  2   scrape_id                                     18086 non-null  int64
#  3   last_scraped                                  18086 non-null  object
#  4   source                                        18086 non-null  object
#  5   name                                          18086 non-null  object
#  6   description                                   17968 non-null  object
#  7   neighborhood_overview                         10108 non-null  object
#  8   picture_url                                   18086 non-null  object
#  9   host_id                                       18086 non-null  int64
#  10  host_url                                      18086 non-null  object
#  11  host_name                                     18084 non-null  object
#  12  host_since                                    18084 non-null  object
#  13  host_location                                 14028 non-null  object
#  14  host_about                                    11388 non-null  object
#  15  host_response_time                            15123 non-null  object
#  16  host_response_rate                            15123 non-null  object
#  17  host_acceptance_rate                          15401 non-null  object
#  18  host_is_superhost                             17667 non-null  object
#  19  host_thumbnail_url                            18084 non-null  object
#  20  host_picture_url                              18084 non-null  object
#  21  host_neighbourhood                            9541 non-null   object
#  22  host_listings_count                           18084 non-null  float64
#  23  host_total_listings_count                     18084 non-null  float64
#  24  host_verifications                            18084 non-null  object
#  25  host_has_profile_pic                          18084 non-null  object
#  26  host_identity_verified                        18084 non-null  object
#  27  neighbourhood                                 10108 non-null  object
#  28  neighbourhood_cleansed                        18086 non-null  object
#  29  neighbourhood_group_cleansed                  18086 non-null  object
#  30  latitude                                      18086 non-null  float64
#  31  longitude                                     18086 non-null  float64
#  32  property_type                                 18086 non-null  object
#  33  room_type                                     18086 non-null  object
#  34  accommodates                                  18086 non-null  int64
#  35  bathrooms                                     0 non-null      float64
#  36  bathrooms_text                                18077 non-null  object
#  37  bedrooms                                      11726 non-null  float64
#  38  beds                                          17772 non-null  float64
#  39  amenities                                     18086 non-null  object
#  40  price                                         18086 non-null  object
#  41  minimum_nights                                18086 non-null  int64
#  42  maximum_nights                                18086 non-null  int64
#  43  minimum_minimum_nights                        18086 non-null  int64
#  44  maximum_minimum_nights                        18086 non-null  int64
#  45  minimum_maximum_nights                        18086 non-null  int64
#  46  maximum_maximum_nights                        18086 non-null  int64
#  47  minimum_nights_avg_ntm                        18086 non-null  float64
#  48  maximum_nights_avg_ntm                        18086 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              18086 non-null  object
#  51  availability_30                               18086 non-null  int64
#  52  availability_60                               18086 non-null  int64
#  53  availability_90                               18086 non-null  int64
#  54  availability_365                              18086 non-null  int64
#  55  calendar_last_scraped                         18086 non-null  object
#  56  number_of_reviews                             18086 non-null  int64
#  57  number_of_reviews_ltm                         18086 non-null  int64
#  58  number_of_reviews_l30d                        18086 non-null  int64
#  59  first_review                                  13620 non-null  object
#  60  last_review                                   13620 non-null  object
#  61  review_scores_rating                          13620 non-null  float64
#  62  review_scores_accuracy                        13537 non-null  float64
#  63  review_scores_cleanliness                     13538 non-null  float64
#  64  review_scores_checkin                         13533 non-null  float64
#  65  review_scores_communication                   13539 non-null  float64
#  66  review_scores_location                        13534 non-null  float64
#  67  review_scores_value                           13533 non-null  float64
#  68  license                                       12322 non-null  object
#  69  instant_bookable                              18086 non-null  object
#  70  calculated_host_listings_count                18086 non-null  int64
#  71  calculated_host_listings_count_entire_homes   18086 non-null  int64
#  72  calculated_host_listings_count_private_rooms  18086 non-null  int64
#  73  calculated_host_listings_count_shared_rooms   18086 non-null  int64
#  74  reviews_per_month                             13620 non-null  float64
# dtypes: float64(18), int64(21), object(36)
# memory usage: 10.3+ MB

# %% [markdown]
# ## 2. Cleaning dataset

# %%
# First off, we are going to sanitize column names, converting them to snakecase in case they are not already

# Defining function to convert column names into snakecase
def snakecase_columns(df: pd.DataFrame) -> pd.DataFrame:
    
    '''
    Converts the name of a columns of a dataframe to snakecase (lowercase with '_' instead of white spaces), and replaces any instance of neighborhood      with neighbourhood (for consistency)
    Input: pd.DataFrame
    Output: pd.DataFrame with snakecase column names
    '''

    snakecase_cols = []

    for col in df.columns:
        col = col.lower().replace(' ', '_')
        col = col.replace('neighborhood', 'neighbourhood')
        snakecase_cols.append(col)

    df.columns = snakecase_cols

    return df

# Applying function to data
data = snakecase_columns(data)
data.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighbourhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
# Checking for duplicated rows

print(f'Number of fully duplicated rows in the dataset: {data.duplicated().sum()}')
# Out:
# Number of fully duplicated rows in the dataset: 0

# %%
# We are not going to use all the columns, we need to select which ones we want and which ones we don't

# Let's see how many columns have unique values in every row
unique_vals_rows = [col for col in data.columns if data[col].nunique() == len(data)]

print(f'Columns with unique values in every row: {unique_vals_rows}')
# Out:
# Columns with unique values in every row: ['id', 'listing_url']

# %%
# We are not going to use any of them, therefore let's drop them

data = data.drop(columns=unique_vals_rows)

print(f'Number of columns in the dataset: {data.shape[1]}')
# Out:
# Number of columns in the dataset: 73

# %%
# Checking duplicates again after dropping columns with unique values in every row

print(f'Number of fully duplicated rows in the dataset: {data.duplicated().sum()}')
# Out:
# Number of fully duplicated rows in the dataset: 9

# %%
# We are getting new duplicates once we have gotten rid of those two columns

dupes = data[data.duplicated() == True]

dupes
# Out:
#             scrape_id last_scraped       source  \
# 14433  20230906022853   2023-09-06  city scrape
# 14434  20230906022853   2023-09-06  city scrape
# 14437  20230906022853   2023-09-06  city scrape
# 14438  20230906022853   2023-09-06  city scrape
# 14439  20230906022853   2023-09-06  city scrape
# 14442  20230906022853   2023-09-06  city scrape
# 14443  20230906022853   2023-09-06  city scrape
# 14453  20230906022853   2023-09-06  city scrape
# 15311  20230906022853   2023-09-06  city scrape
#
#                                                     name  \
# 14433  Hotel in Barcelona · 1 bedroom · 1 bed · 1 pri...
# 14434  Hotel in Barcelona · 1 bedroom · 1 bed · 1 pri...
# 14437  Hotel in Barcelona · 1 bedroom · 1 bed · 1 pri...
# 14438  Hotel in Barcelona · 1 bedroom · 1 bed · 1 pri...
# 14439  Hotel in Barcelona · 1 bedroom · 1 bed · 1 pri...
# 14442  Hotel in Barcelona · 1 bedroom · 1 bed · 1 pri...
# 14443  Hotel in Barcelona · 1 bedroom · 1 bed · 1 pri...
# 14453  Hotel in Barcelona · 1 bedroom · 1 bed · 1 pri...
# 15311  Rental unit in Barcelona · 4 bedrooms · 1 bed ...
#
#                                              description  \
# 14433  Disfruta del fácil acceso a tiendas y restaura...
# 14434  Disfruta del fácil acceso a tiendas y restaura...
# 14437  Disfruta del fácil acceso a tiendas y restaura...
# 14438  Disfruta del fácil acceso a tiendas y restaura...
# 14439  Disfruta del fácil acceso a tiendas y restaura...
# 14442  Disfruta del fácil acceso a tiendas y restaura...
# 14443  Disfruta del fácil acceso a tiendas y restaura...
# 14453  Disfruta del fácil acceso a tiendas y restaura...
# 15311  Preciosa Habitación en piso compartido (4 habi...
#
#       neighbourhood_overview  \
# 14433                    NaN
# 14434                    NaN
# 14437                    NaN
# 14438                    NaN
# 14439                    NaN
# 14442                    NaN
# 14443                    NaN
# 14453                    NaN
# 15311                    NaN
#
#                                              picture_url    host_id  \
# 14433  https://a0.muscache.com/pictures/miso/Hosting-...  470328763
# 14434  https://a0.muscache.com/pictures/miso/Hosting-...  470328763
# 14437  https://a0.muscache.com/pictures/miso/Hosting-...  470328763
# 14438  https://a0.muscache.com/pictures/miso/Hosting-...  470328763
# 14439  https://a0.muscache.com/pictures/miso/Hosting-...  470328763
# 14442  https://a0.muscache.com/pictures/miso/Hosting-...  470328763
# 14443  https://a0.muscache.com/pictures/miso/Hosting-...  470328763
# 14453  https://a0.muscache.com/pictures/miso/Hosting-...  470328763
# 15311  https://a0.muscache.com/pictures/miso/Hosting-...  461820156
#
#                                           host_url host_name  host_since  \
# 14433  https://www.airbnb.com/users/show/470328763    Hostal  2022-07-19
# 14434  https://www.airbnb.com/users/show/470328763    Hostal  2022-07-19
# 14437  https://www.airbnb.com/users/show/470328763    Hostal  2022-07-19
# 14438  https://www.airbnb.com/users/show/470328763    Hostal  2022-07-19
# 14439  https://www.airbnb.com/users/show/470328763    Hostal  2022-07-19
# 14442  https://www.airbnb.com/users/show/470328763    Hostal  2022-07-19
# 14443  https://www.airbnb.com/users/show/470328763    Hostal  2022-07-19
# 14453  https://www.airbnb.com/users/show/470328763    Hostal  2022-07-19
# 15311  https://www.airbnb.com/users/show/461820156   Selling  2022-05-31
#
#           host_location host_about host_response_time host_response_rate  \
# 14433               NaN        NaN     within an hour                97%
# 14434               NaN        NaN     within an hour                97%
# 14437               NaN        NaN     within an hour                97%
# 14438               NaN        NaN     within an hour                97%
# 14439               NaN        NaN     within an hour                97%
# 14442               NaN        NaN     within an hour                97%
# 14443               NaN        NaN     within an hour                97%
# 14453               NaN        NaN     within an hour                97%
# 15311  Barcelona, Spain        NaN     within an hour               100%
#
#       host_acceptance_rate host_is_superhost  \
# 14433                 100%                 f
# 14434                 100%                 f
# 14437                 100%                 f
# 14438                 100%                 f
# 14439                 100%                 f
# 14442                 100%                 f
# 14443                 100%                 f
# 14453                 100%                 f
# 15311                  64%                 f
#
#                                       host_thumbnail_url  \
# 14433  https://a0.muscache.com/im/pictures/user/4351c...
# 14434  https://a0.muscache.com/im/pictures/user/4351c...
# 14437  https://a0.muscache.com/im/pictures/user/4351c...
# 14438  https://a0.muscache.com/im/pictures/user/4351c...
# 14439  https://a0.muscache.com/im/pictures/user/4351c...
# 14442  https://a0.muscache.com/im/pictures/user/4351c...
# 14443  https://a0.muscache.com/im/pictures/user/4351c...
# 14453  https://a0.muscache.com/im/pictures/user/4351c...
# 15311  https://a0.muscache.com/im/pictures/user/40752...
#
#                                         host_picture_url host_neighbourhood  \
# 14433  https://a0.muscache.com/im/pictures/user/4351c...                NaN
# 14434  https://a0.muscache.com/im/pictures/user/4351c...                NaN
# 14437  https://a0.muscache.com/im/pictures/user/4351c...                NaN
# 14438  https://a0.muscache.com/im/pictures/user/4351c...                NaN
# 14439  https://a0.muscache.com/im/pictures/user/4351c...                NaN
# 14442  https://a0.muscache.com/im/pictures/user/4351c...                NaN
# 14443  https://a0.muscache.com/im/pictures/user/4351c...                NaN
# 14453  https://a0.muscache.com/im/pictures/user/4351c...                NaN
# 15311  https://a0.muscache.com/im/pictures/user/40752...                NaN
#
#        host_listings_count  host_total_listings_count  host_verifications  \
# 14433                 35.0                       44.0  ['email', 'phone']
# 14434                 35.0                       44.0  ['email', 'phone']
# 14437                 35.0                       44.0  ['email', 'phone']
# 14438                 35.0                       44.0  ['email', 'phone']
# 14439                 35.0                       44.0  ['email', 'phone']
# 14442                 35.0                       44.0  ['email', 'phone']
# 14443                 35.0                       44.0  ['email', 'phone']
# 14453                 35.0                       44.0  ['email', 'phone']
# 15311                153.0                      174.0  ['email', 'phone']
#
#       host_has_profile_pic host_identity_verified neighbourhood  \
# 14433                    t                      t           NaN
# 14434                    t                      t           NaN
# 14437                    t                      t           NaN
# 14438                    t                      t           NaN
# 14439                    t                      t           NaN
# 14442                    t                      t           NaN
# 14443                    t                      t           NaN
# 14453                    t                      t           NaN
# 15311                    t                      t           NaN
#
#       neighbourhood_cleansed neighbourhood_group_cleansed   latitude  \
# 14433               el Raval                 Ciutat Vella  41.379459
# 14434               el Raval                 Ciutat Vella  41.379459
# 14437               el Raval                 Ciutat Vella  41.379459
# 14438               el Raval                 Ciutat Vella  41.379459
# 14439               el Raval                 Ciutat Vella  41.379459
# 14442               el Raval                 Ciutat Vella  41.379459
# 14443               el Raval                 Ciutat Vella  41.379459
# 14453               el Raval                 Ciutat Vella  41.379459
# 15311               el Raval                 Ciutat Vella  41.377254
#
#        longitude                property_type     room_type  accommodates  \
# 14433   2.166622                Room in hotel  Private room             2
# 14434   2.166622                Room in hotel  Private room             2
# 14437   2.166622                Room in hotel  Private room             2
# 14438   2.166622                Room in hotel  Private room             2
# 14439   2.166622                Room in hotel  Private room             2
# 14442   2.166622                Room in hotel  Private room             2
# 14443   2.166622                Room in hotel  Private room             2
# 14453   2.166622                Room in hotel  Private room             2
# 15311   2.174387  Private room in rental unit  Private room             1
#
#        bathrooms    bathrooms_text  bedrooms  beds  \
# 14433        NaN    1 private bath       1.0   1.0
# 14434        NaN    1 private bath       1.0   1.0
# 14437        NaN    1 private bath       1.0   1.0
# 14438        NaN    1 private bath       1.0   1.0
# 14439        NaN    1 private bath       1.0   1.0
# 14442        NaN    1 private bath       1.0   1.0
# 14443        NaN    1 private bath       1.0   1.0
# 14453        NaN    1 private bath       1.0   1.0
# 15311        NaN  1.5 shared baths       NaN   1.0
#
#                                                amenities   price  \
# 14433  ["TV", "Smoke alarm", "Wifi", "Fire extinguish...  $97.00
# 14434  ["TV", "Smoke alarm", "Wifi", "Fire extinguish...  $97.00
# 14437  ["TV", "Smoke alarm", "Wifi", "Fire extinguish...  $97.00
# 14438  ["TV", "Smoke alarm", "Wifi", "Fire extinguish...  $97.00
# 14439  ["TV", "Smoke alarm", "Wifi", "Fire extinguish...  $97.00
# 14442  ["TV", "Smoke alarm", "Wifi", "Fire extinguish...  $97.00
# 14443  ["TV", "Smoke alarm", "Wifi", "Fire extinguish...  $97.00
# 14453  ["TV", "Smoke alarm", "Wifi", "Fire extinguish...  $97.00
# 15311  ["Refrigerator", "TV", "Wifi", "Oven", "Dining...  $32.00
#
#        minimum_nights  maximum_nights  minimum_minimum_nights  \
# 14433               1             365                       1
# 14434               1             365                       1
# 14437               1             365                       1
# 14438               1             365                       1
# 14439               1             365                       1
# 14442               1             365                       1
# 14443               1             365                       1
# 14453               1             365                       1
# 15311              32              90                      32
#
#        maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 14433                       2                    1125                    1125
# 14434                       2                    1125                    1125
# 14437                       2                    1125                    1125
# 14438                       2                    1125                    1125
# 14439                       2                    1125                    1125
# 14442                       2                    1125                    1125
# 14443                       2                    1125                    1125
# 14453                       2                    1125                    1125
# 15311                      32                      90                      90
#
#        minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 14433                     1.1                  1125.0               NaN
# 14434                     1.1                  1125.0               NaN
# 14437                     1.1                  1125.0               NaN
# 14438                     1.1                  1125.0               NaN
# 14439                     1.1                  1125.0               NaN
# 14442                     1.1                  1125.0               NaN
# 14443                     1.1                  1125.0               NaN
# 14453                     1.1                  1125.0               NaN
# 15311                    32.0                    90.0               NaN
#
#       has_availability  availability_30  availability_60  availability_90  \
# 14433                t               26               56               86
# 14434                t               26               56               86
# 14437                t               26               56               86
# 14438                t               26               56               86
# 14439                t               26               56               86
# 14442                t               26               56               86
# 14443                t               26               56               86
# 14453                t               26               56               86
# 15311                t                0                0                0
#
#        availability_365 calendar_last_scraped  number_of_reviews  \
# 14433               358            2023-09-06                  0
# 14434               358            2023-09-06                  0
# 14437               358            2023-09-06                  0
# 14438               358            2023-09-06                  0
# 14439               358            2023-09-06                  0
# 14442               358            2023-09-06                  0
# 14443               358            2023-09-06                  0
# 14453               358            2023-09-06                  0
# 15311               127            2023-09-06                  0
#
#        number_of_reviews_ltm  number_of_reviews_l30d first_review last_review  \
# 14433                      0                       0          NaN         NaN
# 14434                      0                       0          NaN         NaN
# 14437                      0                       0          NaN         NaN
# 14438                      0                       0          NaN         NaN
# 14439                      0                       0          NaN         NaN
# 14442                      0                       0          NaN         NaN
# 14443                      0                       0          NaN         NaN
# 14453                      0                       0          NaN         NaN
# 15311                      0                       0          NaN         NaN
#
#        review_scores_rating  review_scores_accuracy  \
# 14433                   NaN                     NaN
# 14434                   NaN                     NaN
# 14437                   NaN                     NaN
# 14438                   NaN                     NaN
# 14439                   NaN                     NaN
# 14442                   NaN                     NaN
# 14443                   NaN                     NaN
# 14453                   NaN                     NaN
# 15311                   NaN                     NaN
#
#        review_scores_cleanliness  review_scores_checkin  \
# 14433                        NaN                    NaN
# 14434                        NaN                    NaN
# 14437                        NaN                    NaN
# 14438                        NaN                    NaN
# 14439                        NaN                    NaN
# 14442                        NaN                    NaN
# 14443                        NaN                    NaN
# 14453                        NaN                    NaN
# 15311                        NaN                    NaN
#
#        review_scores_communication  review_scores_location  \
# 14433                          NaN                     NaN
# 14434                          NaN                     NaN
# 14437                          NaN                     NaN
# 14438                          NaN                     NaN
# 14439                          NaN                     NaN
# 14442                          NaN                     NaN
# 14443                          NaN                     NaN
# 14453                          NaN                     NaN
# 15311                          NaN                     NaN
#
#        review_scores_value   license instant_bookable  \
# 14433                  NaN  HB004232                t
# 14434                  NaN  HB004232                t
# 14437                  NaN  HB004232                t
# 14438                  NaN  HB004232                t
# 14439                  NaN  HB004232                t
# 14442                  NaN  HB004232                t
# 14443                  NaN  HB004232                t
# 14453                  NaN  HB004232                t
# 15311                  NaN       NaN                f
#
#        calculated_host_listings_count  \
# 14433                              35
# 14434                              35
# 14437                              35
# 14438                              35
# 14439                              35
# 14442                              35
# 14443                              35
# 14453                              35
# 15311                             150
#
#        calculated_host_listings_count_entire_homes  \
# 14433                                            0
# 14434                                            0
# 14437                                            0
# 14438                                            0
# 14439                                            0
# 14442                                            0
# 14443                                            0
# 14453                                            0
# 15311                                            0
#
#        calculated_host_listings_count_private_rooms  \
# 14433                                            35
# 14434                                            35
# 14437                                            35
# 14438                                            35
# 14439                                            35
# 14442                                            35
# 14443                                            35
# 14453                                            35
# 15311                                           150
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# 14433                                            0                NaN
# 14434                                            0                NaN
# 14437                                            0                NaN
# 14438                                            0                NaN
# 14439                                            0                NaN
# 14442                                            0                NaN
# 14443                                            0                NaN
# 14453                                            0                NaN
# 15311                                            0                NaN

# %%
# It appears we had duplicated records with a different id, probably reposts of the same AirBnB, let's drop them

data = data.drop_duplicates()

print(f'Number of fully duplicated rows in the dataset: {data.duplicated().sum()}')
# Out:
# Number of fully duplicated rows in the dataset: 0

# %%
# Placeholder function to remove 'url' columns

# %%
# Based on the data dictionary available in the webpage where we got the dataset from, let's identify some more columns we do not need
# # Url of the data dictionary: https://docs.google.com/spreadsheets/d/1iWCNJcSutYqpULSQHlNyGInUvHg2BoUGoNRIGa6Szc4/edit#gid=1322284596

cols_to_remove = ['scrape_id', 'host_location', 'last_scraped', 'source', 'name', 'description', 'neighbourhood_overview', 'picture_url', 'host_url', 'host_name', 'host_about', 'host_thumbnail_url', 'host_picture_url', 'amenities', 'host_neighbourhood', 'host_listings_count', 'host_verifications', 'neighbourhood', 'latitude', 'longitude', 'bathrooms', 'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'property_type', 'calendar_updated', 'availability_60', 'availability_90', 'availability_365', 'calendar_last_scraped', 'number_of_reviews', 'number_of_reviews_l30d', 'last_review', 'license', 'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms', 'number_of_reviews_ltm', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'host_total_listings_count', 'neighbourhood_cleansed']

data = data.drop(columns=cols_to_remove)

print(f'Number of columns in the dataset: {data.shape[1]}')
# Out:
# Number of columns in the dataset: 24

# %%
# Checking for nulls

nulls = pd.DataFrame(data.isna().sum(), columns=['nulls'])

nulls['percent'] = round(nulls.iloc[:, 0] / len(data), 2)

nulls
# Out:
#                                 nulls  percent
# host_id                             0     0.00
# host_since                          2     0.00
# host_response_time               2963     0.16
# host_response_rate               2963     0.16
# host_acceptance_rate             2685     0.15
# host_is_superhost                 419     0.02
# host_has_profile_pic                2     0.00
# host_identity_verified              2     0.00
# neighbourhood_group_cleansed        0     0.00
# room_type                           0     0.00
# accommodates                        0     0.00
# bathrooms_text                      9     0.00
# bedrooms                         6359     0.35
# beds                              314     0.02
# price                               0     0.00
# minimum_nights                      0     0.00
# maximum_nights                      0     0.00
# has_availability                    0     0.00
# availability_30                     0     0.00
# first_review                     4457     0.25
# review_scores_rating             4457     0.25
# instant_bookable                    0     0.00
# calculated_host_listings_count      0     0.00
# reviews_per_month                4457     0.25

# %%
data['beds'].mean()
# Out:
# 2.3583854078702924

# %%
data['bedrooms'].mean()
# Out:
# 2.066478921317631

# %%
# Removing rows from columns with a handful of nulls

data = data.dropna(subset=['host_since', 'bathrooms_text'])

data.isna().sum()
# Out:
# host_id                              0
# host_since                           0
# host_response_time                2961
# host_response_rate                2961
# host_acceptance_rate              2683
# host_is_superhost                  419
# host_has_profile_pic                 0
# host_identity_verified               0
# neighbourhood_group_cleansed         0
# room_type                            0
# accommodates                         0
# bathrooms_text                       0
# bedrooms                          6355
# beds                               314
# price                                0
# minimum_nights                       0
# maximum_nights                       0
# has_availability                     0
# availability_30                      0
# first_review                      4454
# review_scores_rating              4454
# instant_bookable                     0
# calculated_host_listings_count       0
# reviews_per_month                 4454
# dtype: int64

# %%
# Imputing median in the beds column

data['beds'] = data['beds'].fillna(data['beds'].median())

data['beds'].isna().sum()
# Out:
# 0

# %%
data['host_is_superhost'].value_counts(dropna=False)
# Out:
# host_is_superhost
# f      14564
# t       3083
# NaN      419
# Name: count, dtype: int64

# %%
# Replacing nulls in host_is_superhost with the mode

data['host_is_superhost'].fillna(data['host_is_superhost'].mode().iloc[0], inplace=True)

data['host_is_superhost'].value_counts(dropna=False)
# Out:
# host_is_superhost
# f    14983
# t     3083
# Name: count, dtype: int64

# %%
# Replacing nulls in bedrooms with values from beds column

data['bedrooms'] = data['bedrooms'].fillna(data['beds'])

data['bedrooms'].isna().sum()
# Out:
# 0

# %%
data.isna().sum()
# Out:
# host_id                              0
# host_since                           0
# host_response_time                2961
# host_response_rate                2961
# host_acceptance_rate              2683
# host_is_superhost                    0
# host_has_profile_pic                 0
# host_identity_verified               0
# neighbourhood_group_cleansed         0
# room_type                            0
# accommodates                         0
# bathrooms_text                       0
# bedrooms                             0
# beds                                 0
# price                                0
# minimum_nights                       0
# maximum_nights                       0
# has_availability                     0
# availability_30                      0
# first_review                      4454
# review_scores_rating              4454
# instant_bookable                     0
# calculated_host_listings_count       0
# reviews_per_month                 4454
# dtype: int64

# %% [markdown]
# Nulls considerations:
# - We consider the columns that still have nulls relevant for the business analysis and prediction, therefore we are going to drop the rows with nulls
# - Most likely, the cols related to reviews will be missing for new listings, but we do not have the means to check it without a date column
# - The host related columns will most likely be related to the host_since column, but we cannot rely on that since it could mean they signed up as guests
# - We will still have a good amount of rows to conduct our business analysis and prediction

# %%
data = data.dropna(subset='first_review')
data.isna().sum()
# Out:
# host_id                              0
# host_since                           0
# host_response_time                1881
# host_response_rate                1881
# host_acceptance_rate              1585
# host_is_superhost                    0
# host_has_profile_pic                 0
# host_identity_verified               0
# neighbourhood_group_cleansed         0
# room_type                            0
# accommodates                         0
# bathrooms_text                       0
# bedrooms                             0
# beds                                 0
# price                                0
# minimum_nights                       0
# maximum_nights                       0
# has_availability                     0
# availability_30                      0
# first_review                         0
# review_scores_rating                 0
# instant_bookable                     0
# calculated_host_listings_count       0
# reviews_per_month                    0
# dtype: int64

# %%
data = data.dropna(subset='host_response_time')
data.isna().sum()
# Out:
# host_id                            0
# host_since                         0
# host_response_time                 0
# host_response_rate                 0
# host_acceptance_rate              42
# host_is_superhost                  0
# host_has_profile_pic               0
# host_identity_verified             0
# neighbourhood_group_cleansed       0
# room_type                          0
# accommodates                       0
# bathrooms_text                     0
# bedrooms                           0
# beds                               0
# price                              0
# minimum_nights                     0
# maximum_nights                     0
# has_availability                   0
# availability_30                    0
# first_review                       0
# review_scores_rating               0
# instant_bookable                   0
# calculated_host_listings_count     0
# reviews_per_month                  0
# dtype: int64

# %%
# There are several features, mostly neighbourhood names, that have values with special characters. We can rely on unidecode to sanitize then

from unidecode import unidecode

def remove_accents(input: str) -> str:
    '''
    Removes accents and other letter punctuation symbols for letters and returns the converted string.
    '''
    return unidecode(input)

data['neighbourhood_group_cleansed'] = data['neighbourhood_group_cleansed'].apply(remove_accents)

data['neighbourhood_group_cleansed'].unique()
# Out:
# array(['Eixample', 'Sant Marti', 'Gracia', 'Sants-Montjuic',
#        'Ciutat Vella', 'Les Corts', 'Horta-Guinardo',
#        'Sarria-Sant Gervasi', 'Sant Andreu', 'Nou Barris'], dtype=object)

# %%
# Checking data type of columns

data.dtypes
# Out:
# host_id                             int64
# host_since                         object
# host_response_time                 object
# host_response_rate                 object
# host_acceptance_rate               object
# host_is_superhost                  object
# host_has_profile_pic               object
# host_identity_verified             object
# neighbourhood_group_cleansed       object
# room_type                          object
# accommodates                        int64
# bathrooms_text                     object
# bedrooms                          float64
# beds                              float64
# price                              object
# minimum_nights                      int64
# maximum_nights                      int64
# has_availability                   object
# availability_30                     int64
# first_review                       object
# review_scores_rating              float64
# instant_bookable                   object
# calculated_host_listings_count      int64
# reviews_per_month                 float64
# dtype: object

# %%
data.head()
# Out:
#    host_id  host_since  host_response_time host_response_rate  \
# 0    71615  2010-01-19      within an hour                97%
# 1    90417  2010-03-09      within an hour               100%
# 2   567180  2011-05-08  within a few hours                88%
# 3   135703  2010-05-31      within an hour               100%
# 4   567180  2011-05-08  within a few hours                88%
#
#   host_acceptance_rate host_is_superhost host_has_profile_pic  \
# 0                  90%                 f                    t
# 1                  94%                 t                    t
# 2                  98%                 f                    t
# 3                 100%                 f                    t
# 4                  98%                 f                    t
#
#   host_identity_verified neighbourhood_group_cleansed        room_type  \
# 0                      t                     Eixample  Entire home/apt
# 1                      t                   Sant Marti  Entire home/apt
# 2                      f                     Eixample  Entire home/apt
# 3                      t                       Gracia  Entire home/apt
# 4                      f                     Eixample  Entire home/apt
#
#    accommodates bathrooms_text  bedrooms  beds    price  minimum_nights  \
# 0             8        2 baths       3.0   6.0  $202.00               1
# 1             5        2 baths       3.0   4.0  $255.00               3
# 2             8        2 baths       3.0   6.0  $331.00               2
# 3             6      1.5 baths       2.0   3.0  $171.00              21
# 4             8      2.5 baths       3.0   5.0  $333.00               2
#
#    maximum_nights has_availability  availability_30 first_review  \
# 0            1125                t                4   2013-05-27
# 1             300                t               16   2011-03-15
# 2              30                f                0   2011-08-09
# 3              31                t                6   2011-07-17
# 4              28                f                0   2011-09-13
#
#    review_scores_rating instant_bookable  calculated_host_listings_count  \
# 0                  4.30                t                              30
# 1                  4.77                f                               2
# 2                  4.55                f                              19
# 3                  4.46                t                               3
# 4                  4.56                f                              19
#
#    reviews_per_month
# 0               0.30
# 1               0.48
# 2               0.33
# 3               0.64
# 4               0.34

# %% [markdown]
# Columns with incorrect data types and what type they should have:
# - host_since: datetime
# - host_response_rate: float
# - host_acceptance_rate: float
# - price: float
# - bathrooms_text: float

# %%
# Converting columns to correct datatypes

# host_since to datetime
data['host_since'] = pd.to_datetime(data['host_since'], format='%Y-%m-%d')
data['first_review'] = pd.to_datetime(data['first_review'], format='%Y-%m-%d')

data.dtypes
# Out:
# host_id                                    int64
# host_since                        datetime64[ns]
# host_response_time                        object
# host_response_rate                        object
# host_acceptance_rate                      object
# host_is_superhost                         object
# host_has_profile_pic                      object
# host_identity_verified                    object
# neighbourhood_group_cleansed              object
# room_type                                 object
# accommodates                               int64
# bathrooms_text                            object
# bedrooms                                 float64
# beds                                     float64
# price                                     object
# minimum_nights                             int64
# maximum_nights                             int64
# has_availability                          object
# availability_30                            int64
# first_review                      datetime64[ns]
# review_scores_rating                     float64
# instant_bookable                          object
# calculated_host_listings_count             int64
# reviews_per_month                        float64
# dtype: object

# %%
# host_response_rate and host_acceptance_rate to float

def remove_percent_div_100(input_str: str) -> float:
    '''
    Takes a string, removes the % symbol, converts it to a float and divides it by 100.
    '''
    if isinstance(input_str, str):
        converted_value = input_str.replace('%', '')
        divided_value = float(converted_value) / 100
    else:
        return input_str
    return divided_value

data['host_response_rate'] = data['host_response_rate'].apply(remove_percent_div_100)
data['host_acceptance_rate'] = data['host_acceptance_rate'].apply(remove_percent_div_100)

data['host_response_rate']
# Out:
# 0        0.97
# 1        1.00
# 2        0.88
# 3        1.00
# 4        0.88
#          ...
# 17988    1.00
# 17999    1.00
# 18002    1.00
# 18006    1.00
# 18008    1.00
# Name: host_response_rate, Length: 11731, dtype: float64

# %%
# Replacing nulls in host_acceptance_rate with the mean, now that the column does not contain any nulls

data['host_acceptance_rate'] = data['host_acceptance_rate'].fillna(data['host_acceptance_rate'].mean())

data['host_acceptance_rate'].isna().sum()
# Out:
# 0

# %%
# price to float

def remove_dollar_symbol_commas(input_str: str) -> float:
    '''
    Takes a string, removes the $ symbol and converts it to a float.
    '''
    if isinstance(input_str, str):
        no_dollar = input_str.replace('$', '')
        no_comma = no_dollar.replace(',', '')
        float_val = float(no_comma)
    else:
        return input_str
    return float_val

data['price'] = data['price'].apply(remove_dollar_symbol_commas)

data['price']
# Out:
# 0        202.0
# 1        255.0
# 2        331.0
# 3        171.0
# 4        333.0
#          ...
# 17988    105.0
# 17999    116.0
# 18002     52.0
# 18006    116.0
# 18008    116.0
# Name: price, Length: 11731, dtype: float64

# %%
# Checking unique values of bathroom_text to decide the approach

data['bathrooms_text']
# Out:
# 0          2 baths
# 1          2 baths
# 2          2 baths
# 3        1.5 baths
# 4        2.5 baths
#            ...
# 17988       1 bath
# 17999       1 bath
# 18002       1 bath
# 18006       1 bath
# 18008       1 bath
# Name: bathrooms_text, Length: 11731, dtype: object

# %%
# bathrooms_text to float

mapping_dict = {'Half-bath': '0.5', 'Shared half-bath': '0.5', 'Private half-bath': '0.5'}

data['bathrooms_text'] = data['bathrooms_text'].replace(mapping_dict)

data['bathrooms_text'] = data['bathrooms_text'].str.split().str[0]

data['bathrooms_text'] = data['bathrooms_text'].astype(float)

data['bathrooms_text'].unique()
# Out:
# array([ 2. ,  1.5,  2.5,  3. ,  1. ,  3.5,  4. ,  5.5,  7.5,  4.5,  6. ,
#         0.5,  0. ,  5. ,  8. , 10. ,  6.5])

# %%
# Checking the shape of our dataset after cleaning

data.shape
# Out:
# (11731, 24)

# %%
# Resetting index

data = data.reset_index(drop=True)

# %%
# Exporting cleaned dataset to a csv file

data.to_csv('data/cleaned/listings_cleaned.csv', index=False)

# %%
data.dtypes
# Out:
# host_id                                    int64
# host_since                        datetime64[ns]
# host_response_time                        object
# host_response_rate                       float64
# host_acceptance_rate                     float64
# host_is_superhost                         object
# host_has_profile_pic                      object
# host_identity_verified                    object
# neighbourhood_group_cleansed              object
# room_type                                 object
# accommodates                               int64
# bathrooms_text                           float64
# bedrooms                                 float64
# beds                                     float64
# price                                    float64
# minimum_nights                             int64
# maximum_nights                             int64
# has_availability                          object
# availability_30                            int64
# first_review                      datetime64[ns]
# review_scores_rating                     float64
# instant_bookable                          object
# calculated_host_listings_count             int64
# reviews_per_month                        float64
# dtype: object
